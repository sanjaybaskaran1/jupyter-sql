# %%
# %reload_ext sql

# %%
# %sql mysql+pymysql://root:easwari@localhost

# %%
# %%sql
# use window_functions;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %% [markdown]
# --> problem is based on string aggregation use {group_concat()} --> function for string aggregation

# %% [markdown]
# KPMG -- HARD LEVEL INTERVIEW QUESTION

# %% [markdown]
# ![image.png](attachment:137354a9-cb52-41ed-9a33-57b6e8e8b812.png)

# %%
# %%sql
# select * from users;
# Out:
#  * mysql+pymysql://root:***@localhost
# 6 rows affected.
# [('A', 'BANGALORE', 'A@GMAIL.COM', 1, 'CPU'),
#  ('A', 'BANGALORE', 'A1@GMAIL.COM', 1, 'CPU'),
#  ('A', 'BANGALORE', 'A2@GMAIL.COM', 2, 'DESKTOP'),
#  ('B', 'BANGALORE', 'B@GMAIL.COM', 2, 'DESKTOP'),
#  ('B', 'BANGALORE', 'B1@GMAIL.COM', 2, 'DESKTOP'),
#  ('B', 'BANGALORE', 'B2@GMAIL.COM', 1, 'MONITOR')]

# %%
# %%sql
# select name, resources
# from users
# group by name, resources;
# Out:
#  * mysql+pymysql://root:***@localhost
# 4 rows affected.
# [('A', 'CPU'), ('A', 'DESKTOP'), ('B', 'DESKTOP'), ('B', 'MONITOR')]

# %%
# %%sql
# with unique_name_$_resources as
# (
# select name, resources
# from users
# group by name, resources
# )
# select name, group_concat(resources, ' ') as "Resources"
# from unique_name_$_resources
# group by name;
# Out:
#  * mysql+pymysql://root:***@localhost
# 2 rows affected.
# [('A', 'CPU ,DESKTOP '), ('B', 'DESKTOP ,MONITOR ')]

# %%
# %%sql
# with unique_name_$_resources as
# (
# select name, resources
# from users
# group by name, resources
# )
# , cte2 as
# (
# select name, group_concat(resources, ' ') as "Resources"
# from unique_name_$_resources
# group by name
# )
# select t2.name, t2.Resources,count(u.floor) as "total_floor_visits"
# from users as `u` inner join cte2 as `t2`
# on u.name = t2.name
# group by u.name;
# Out:
#  * mysql+pymysql://root:***@localhost
# 2 rows affected.
# [('A', 'CPU ,DESKTOP ', 3), ('B', 'DESKTOP ,MONITOR ', 3)]

# %%
# %%sql
# with unique_name_$_resources as
# (
# select name, resources
# from users
# group by name, resources
# )
# , cte2 as
# (
# select name, group_concat(resources, ' ') as "Resources"
# from unique_name_$_resources
# group by name
# )
# , cte3 as
# (
# select t2.name, t2.Resources,count(u.floor) as "total_floor_visits"
# from users as `u` inner join cte2 as `t2`
# on u.name = t2.name
# group by u.name
# )
# select t2.name,t2.resources, t2.total_floor_visits, u.floor
# from users as u inner join cte3 as t2
# on u.name = t2.name;
# Out:
#  * mysql+pymysql://root:***@localhost
# 6 rows affected.
# [('A', 'CPU ,DESKTOP ', 3, 1),
#  ('A', 'CPU ,DESKTOP ', 3, 1),
#  ('A', 'CPU ,DESKTOP ', 3, 2),
#  ('B', 'DESKTOP ,MONITOR ', 3, 2),
#  ('B', 'DESKTOP ,MONITOR ', 3, 2),
#  ('B', 'DESKTOP ,MONITOR ', 3, 1)]

# %%
# %%sql
# with unique_name_$_resources as
# (
# select name, resources
# from users
# group by name, resources
# )
# , cte2 as
# (
# select name, group_concat(resources, ' ') as "Resources"
# from unique_name_$_resources
# group by name
# )
# , cte3 as
# (
# select t2.name, t2.Resources,count(u.floor) as "total_floor_visits"
# from users as `u` inner join cte2 as `t2`
# on u.name = t2.name
# group by u.name
# )
# , cte4 as
# (
# select t2.name,t2.resources, t2.total_floor_visits, u.floor
# from users as u inner join cte3 as t2
# on u.name = t2.name
# )
# select name,resources,total_floor_visits,floor as "most_visited_floor"
# from cte4
# group by name,resources,total_floor_visits,floor
# having count(floor) > 1;
# Out:
#  * mysql+pymysql://root:***@localhost
# 2 rows affected.
# [('A', 'CPU ,DESKTOP ', 3, 1), ('B', 'DESKTOP ,MONITOR ', 3, 2)]

# %% [markdown]
# ## ------------------------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:f91f9f60-32f7-4864-87d8-f88dd2f99143.png)

# %%
# %sql postgresql://postgres:easwari@localhost:5432/window_functions

# %%
# %%sql
# select * from Combo;
# Out:
#  * postgresql://postgres:***@localhost:5432/window_functions
# 8 rows affected.
# [('A,B,C', 90),
#  ('B,C,A', 20),
#  ('C,A,B', 30),
#  ('Z,X,Y', 10),
#  ('X,Z,Y', 20),
#  ('X,Y,Z', 30),
#  ('P,X,Y', 100),
#  ('X,P,Y', 200)]

# %%
# %%sql
# select *,
# unnest(string_to_array(combo, ',')) as "split_combo"
# from Combo;
# Out:
#  * postgresql://postgres:***@localhost:5432/window_functions
# 24 rows affected.
# [('A,B,C', 90, 'A'),
#  ('A,B,C', 90, 'B'),
#  ('A,B,C', 90, 'C'),
#  ('B,C,A', 20, 'B'),
#  ('B,C,A', 20, 'C'),
#  ('B,C,A', 20, 'A'),
#  ('C,A,B', 30, 'C'),
#  ('C,A,B', 30, 'A'),
#  ('C,A,B', 30, 'B'),
#  ('Z,X,Y', 10, 'Z'),
#  ('Z,X,Y', 10, 'X'),
#  ('Z,X,Y', 10, 'Y'),
#  ('X,Z,Y', 20, 'X'),
#  ('X,Z,Y', 20, 'Z'),
#  ('X,Z,Y', 20, 'Y'),
#  ('X,Y,Z', 30, 'X'),
#  ('X,Y,Z', 30, 'Y'),
#  ('X,Y,Z', 30, 'Z'),
#  ('P,X,Y', 100, 'P'),
#  ('P,X,Y', 100, 'X'),
#  ('P,X,Y', 100, 'Y'),
#  ('X,P,Y', 200, 'X'),
#  ('X,P,Y', 200, 'P'),
#  ('X,P,Y', 200, 'Y')]

# %%
# %%sql
# with split_string as
# (
# select combo, cost,
# unnest(string_to_array(combo, ',')) as "split_combo"
# from combo
# )
# select combo,cost,
# string_agg(split_combo, ','  ORDER BY split_combo ASC) as "merged_combo"
# from split_string
# group by combo, cost;
# Out:
#  * postgresql://postgres:***@localhost:5432/window_functions
# 8 rows affected.
# [('A,B,C', 90, 'A,B,C'),
#  ('B,C,A', 20, 'A,B,C'),
#  ('C,A,B', 30, 'A,B,C'),
#  ('P,X,Y', 100, 'P,X,Y'),
#  ('X,P,Y', 200, 'P,X,Y'),
#  ('X,Y,Z', 30, 'X,Y,Z'),
#  ('X,Z,Y', 20, 'X,Y,Z'),
#  ('Z,X,Y', 10, 'X,Y,Z')]

# %%
# %%sql
# with split_string as
# (
# select combo, cost,
# unnest(string_to_array(combo, ',')) as "split_combo"
# from combo
# )
# , merged_string as
# (
# select combo,cost,
# string_agg(split_combo, ','  ORDER BY split_combo ASC) as "merged_combo"
# from split_string
# group by combo, cost
# )
# select *
# from merged_string
# where combo = merged_combo;
# Out:
#  * postgresql://postgres:***@localhost:5432/window_functions
# 3 rows affected.
# [('A,B,C', 90, 'A,B,C'), ('P,X,Y', 100, 'P,X,Y'), ('X,Y,Z', 30, 'X,Y,Z')]

# %% [markdown]
# ## --------------------------------------------------------------------------------
