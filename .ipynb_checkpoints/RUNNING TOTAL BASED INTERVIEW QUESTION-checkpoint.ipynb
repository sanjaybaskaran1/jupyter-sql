# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:easwari@localhost

# %%
# %%sql
# show databases;
# Out:
#  * mysql+pymysql://root:***@localhost
# 15 rows affected.
# [('employees',),
#  ('events',),
#  ('functions',),
#  ('information_schema',),
#  ('joins',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sales',),
#  ('set operations',),
#  ('students',),
#  ('subqueries',),
#  ('sys',),
#  ('triggers',),
#  ('window functions interview questuions',),
#  ('window_functions',)]

# %%
# %%sql
# use `window functions interview questuions`;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# show tables;
# Out:
#  * mysql+pymysql://root:***@localhost
# 4 rows affected.
# [('students',), ('students_new',), ('table a',), ('table b',)]

# %% [markdown]
# ![image.png](attachment:80ca7f5f-6110-4fe4-ad47-28e7e2931b7e.png)

# %%
# %%sql
# CREATE TABLE products (
#     productid INT PRIMARY KEY,
#     category VARCHAR(50),
#     price DECIMAL(10, 2)
# );
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO products (productid, category, price)
# VALUES
#     (1, 'Home & Living', 2000),
#     (2, 'Home & Living', 3500),
#     (3, 'Home & Living', 15000),
#     (4, 'Kids', 1200),
#     (5, 'Kids', 1500),
#     (6, 'Kids', 6000),
#     (7, 'Gifts', 500),
#     (8, 'Gifts', 600),
#     (9, 'Gifts', 4500);
# Out:
#  * mysql+pymysql://root:***@localhost
# 9 rows affected.
# []

# %%
# %%sql
# select * from products;
# Out:
#  * mysql+pymysql://root:***@localhost
# 9 rows affected.
# [(1, 'Home & Living', Decimal('2000.00')),
#  (2, 'Home & Living', Decimal('3500.00')),
#  (3, 'Home & Living', Decimal('15000.00')),
#  (4, 'Kids', Decimal('1200.00')),
#  (5, 'Kids', Decimal('1500.00')),
#  (6, 'Kids', Decimal('6000.00')),
#  (7, 'Gifts', Decimal('500.00')),
#  (8, 'Gifts', Decimal('600.00')),
#  (9, 'Gifts', Decimal('4500.00'))]

# %%
# %%sql
# select *,
# sum(price) over(partition by category rows between unbounded preceding and current row) as `running_total`
# from products;
# Out:
#  * mysql+pymysql://root:***@localhost
# 9 rows affected.
# [(7, 'Gifts', Decimal('500.00'), Decimal('500.00')),
#  (8, 'Gifts', Decimal('600.00'), Decimal('1100.00')),
#  (9, 'Gifts', Decimal('4500.00'), Decimal('5600.00')),
#  (1, 'Home & Living', Decimal('2000.00'), Decimal('2000.00')),
#  (2, 'Home & Living', Decimal('3500.00'), Decimal('5500.00')),
#  (3, 'Home & Living', Decimal('15000.00'), Decimal('20500.00')),
#  (4, 'Kids', Decimal('1200.00'), Decimal('1200.00')),
#  (5, 'Kids', Decimal('1500.00'), Decimal('2700.00')),
#  (6, 'Kids', Decimal('6000.00'), Decimal('8700.00'))]

# %%
# %%sql
# with running_price as
# (
# select *,
# sum(price) over(partition by category rows between unbounded preceding and current row) as `running_total`
# from products
# )
# ,home_and_living as
# (
# select * from running_price
# where category = 'Home & Living' and running_total <= 8800
# )
# , kids as
# (
# select * from running_price
# where category = 'Kids' and running_Total <= 8800 - (select max(running_Total) from home_and_living)
# )
# select * from home_and_living
# union
# select * from kids;
# Out:
#  * mysql+pymysql://root:***@localhost
# 4 rows affected.
# [(1, 'Home & Living', Decimal('2000.00'), Decimal('2000.00')),
#  (2, 'Home & Living', Decimal('3500.00'), Decimal('5500.00')),
#  (4, 'Kids', Decimal('1200.00'), Decimal('1200.00')),
#  (5, 'Kids', Decimal('1500.00'), Decimal('2700.00'))]

# %% [markdown]
# ## -----------------------------------------------------------------------------------

# %% [markdown]
# ## ![image.png](attachment:02fb47f8-0e03-4dba-bb64-9710b4b11969.png)

# %%
# %%sql
# select * from new_sale;
# Out:
#  * mysql+pymysql://root:***@localhost
# 10 rows affected.
# [(datetime.date(2024, 1, 1), 100),
#  (datetime.date(2024, 1, 2), 800),
#  (datetime.date(2024, 1, 3), 1100),
#  (datetime.date(2024, 1, 4), 1200),
#  (datetime.date(2024, 1, 5), 1300),
#  (datetime.date(2024, 1, 6), 1400),
#  (datetime.date(2024, 1, 7), 1500),
#  (datetime.date(2024, 1, 8), 1600),
#  (datetime.date(2024, 1, 9), 1700),
#  (datetime.date(2024, 1, 10), 1800)]

# %%
# %%sql
# select *
# from (new_sale as `t1`) inner join (new_sale as `t2`)
# on t1.date = t2.date;
# Out:
#  * mysql+pymysql://root:***@localhost
# 10 rows affected.
# [(datetime.date(2024, 1, 1), 100, datetime.date(2024, 1, 1), 100),
#  (datetime.date(2024, 1, 2), 800, datetime.date(2024, 1, 2), 800),
#  (datetime.date(2024, 1, 3), 1100, datetime.date(2024, 1, 3), 1100),
#  (datetime.date(2024, 1, 4), 1200, datetime.date(2024, 1, 4), 1200),
#  (datetime.date(2024, 1, 5), 1300, datetime.date(2024, 1, 5), 1300),
#  (datetime.date(2024, 1, 6), 1400, datetime.date(2024, 1, 6), 1400),
#  (datetime.date(2024, 1, 7), 1500, datetime.date(2024, 1, 7), 1500),
#  (datetime.date(2024, 1, 8), 1600, datetime.date(2024, 1, 8), 1600),
#  (datetime.date(2024, 1, 9), 1700, datetime.date(2024, 1, 9), 1700),
#  (datetime.date(2024, 1, 10), 1800, datetime.date(2024, 1, 10), 1800)]

# %%
# %%sql
# select *
# from (new_sale as `t1`) inner join (new_sale as `t2`)
# on t1.date >= t2.date;
# Out:
#  * mysql+pymysql://root:***@localhost
# 55 rows affected.
# [(datetime.date(2024, 1, 10), 1800, datetime.date(2024, 1, 1), 100),
#  (datetime.date(2024, 1, 9), 1700, datetime.date(2024, 1, 1), 100),
#  (datetime.date(2024, 1, 8), 1600, datetime.date(2024, 1, 1), 100),
#  (datetime.date(2024, 1, 7), 1500, datetime.date(2024, 1, 1), 100),
#  (datetime.date(2024, 1, 6), 1400, datetime.date(2024, 1, 1), 100),
#  (datetime.date(2024, 1, 5), 1300, datetime.date(2024, 1, 1), 100),
#  (datetime.date(2024, 1, 4), 1200, datetime.date(2024, 1, 1), 100),
#  (datetime.date(2024, 1, 3), 1100, datetime.date(2024, 1, 1), 100),
#  (datetime.date(2024, 1, 2), 800, datetime.date(2024, 1, 1), 100),
#  (datetime.date(2024, 1, 1), 100, datetime.date(2024, 1, 1), 100),
#  (datetime.date(2024, 1, 10), 1800, datetime.date(2024, 1, 2), 800),
#  (datetime.date(2024, 1, 9), 1700, datetime.date(2024, 1, 2), 800),
#  (datetime.date(2024, 1, 8), 1600, datetime.date(2024, 1, 2), 800),
# ...

# %%
# %%sql
# select t1.date, sum(t2.salary) as "Cummulative sum"
# from (new_sale as `t1`) inner join (new_sale as `t2`)
# on t1.date >= t2.date
# group by t1.date
# order by t1.date;
# Out:
#  * mysql+pymysql://root:***@localhost
# 10 rows affected.
# [(datetime.date(2024, 1, 1), Decimal('100')),
#  (datetime.date(2024, 1, 2), Decimal('900')),
#  (datetime.date(2024, 1, 3), Decimal('2000')),
#  (datetime.date(2024, 1, 4), Decimal('3200')),
#  (datetime.date(2024, 1, 5), Decimal('4500')),
#  (datetime.date(2024, 1, 6), Decimal('5900')),
#  (datetime.date(2024, 1, 7), Decimal('7400')),
#  (datetime.date(2024, 1, 8), Decimal('9000')),
#  (datetime.date(2024, 1, 9), Decimal('10700')),
#  (datetime.date(2024, 1, 10), Decimal('12500'))]

# %%
# %%sql
# select date, salary,
# sum(salary) over(order by date asc) as "Cummulative sum"
# from new_sale;
# Out:
#  * mysql+pymysql://root:***@localhost
# 10 rows affected.
# [(datetime.date(2024, 1, 1), 100, Decimal('100')),
#  (datetime.date(2024, 1, 2), 800, Decimal('900')),
#  (datetime.date(2024, 1, 3), 1100, Decimal('2000')),
#  (datetime.date(2024, 1, 4), 1200, Decimal('3200')),
#  (datetime.date(2024, 1, 5), 1300, Decimal('4500')),
#  (datetime.date(2024, 1, 6), 1400, Decimal('5900')),
#  (datetime.date(2024, 1, 7), 1500, Decimal('7400')),
#  (datetime.date(2024, 1, 8), 1600, Decimal('9000')),
#  (datetime.date(2024, 1, 9), 1700, Decimal('10700')),
#  (datetime.date(2024, 1, 10), 1800, Decimal('12500'))]

# %% [markdown]
# ## ---------------------------------------------------------------------------------------

# %% [markdown]
# ## ![image.png](attachment:f70fba0a-83c4-4d00-b1a0-2062a4d5dc40.png)

# %%
# %%sql
# select created_at, date_format(created_at, '%Y-%m') as "year_month"
# from amazon_purchases;
# Out:
#  * mysql+pymysql://root:***@localhost
# 12 rows affected.
# [(datetime.datetime(2023, 1, 5, 0, 0), '2023-01'),
#  (datetime.datetime(2023, 1, 15, 0, 0), '2023-01'),
#  (datetime.datetime(2023, 2, 10, 0, 0), '2023-02'),
#  (datetime.datetime(2023, 2, 20, 0, 0), '2023-02'),
#  (datetime.datetime(2023, 3, 1, 0, 0), '2023-03'),
#  (datetime.datetime(2023, 3, 15, 0, 0), '2023-03'),
#  (datetime.datetime(2023, 4, 5, 0, 0), '2023-04'),
#  (datetime.datetime(2023, 4, 10, 0, 0), '2023-04'),
#  (datetime.datetime(2023, 5, 1, 0, 0), '2023-05'),
#  (datetime.datetime(2023, 5, 15, 0, 0), '2023-05'),
#  (datetime.datetime(2023, 6, 5, 0, 0), '2023-06'),
#  (datetime.datetime(2023, 6, 15, 0, 0), '2023-06')]

# %%
# %%sql
# select date_format(created_at, '%Y-%m') as "year_month", avg(purchase_amt) as "Avg_Total_Rewenue"
# from amazon_purchases
# group by date_format(created_at, '%Y-%m');
# Out:
#  * mysql+pymysql://root:***@localhost
# 6 rows affected.
# [('2023-01', Decimal('650.0000')),
#  ('2023-02', Decimal('1600.0000')),
#  ('2023-03', Decimal('850.0000')),
#  ('2023-04', Decimal('1800.0000')),
#  ('2023-05', Decimal('2100.0000')),
#  ('2023-06', Decimal('1600.0000'))]

# %%
# %%sql
# select date_format(created_at, '%Y-%m') as "year_month",
# sum(case when purchase_amt > 0 then purchase_amt else 0 end) as "Total amount"
# from amazon_purchases
# group by date_format(created_at, '%Y-%m');
# Out:
#  * mysql+pymysql://root:***@localhost
# 6 rows affected.
# [('2023-01', Decimal('1500')),
#  ('2023-02', Decimal('3200')),
#  ('2023-03', Decimal('1800')),
#  ('2023-04', Decimal('3600')),
#  ('2023-05', Decimal('4200')),
#  ('2023-06', Decimal('3200'))]

# %%
# %%sql
# with cte as
# (
# select date_format(created_at, '%Y-%m') as "year_month", purchase_amt
# from amazon_purchases
# )
# select *,
# avg(purchase_amt) over(order by purchase_amt asc rows between 2 preceding and current row)
# from cte;
# Out:
#  * mysql+pymysql://root:***@localhost
# 12 rows affected.
# [('2023-01', -200, Decimal('-200.0000')),
#  ('2023-03', -100, Decimal('-150.0000')),
#  ('2023-02', 1200, Decimal('300.0000')),
#  ('2023-06', 1300, Decimal('800.0000')),
#  ('2023-04', 1400, Decimal('1300.0000')),
#  ('2023-01', 1500, Decimal('1400.0000')),
#  ('2023-05', 1700, Decimal('1533.3333')),
#  ('2023-03', 1800, Decimal('1666.6667')),
#  ('2023-06', 1900, Decimal('1800.0000')),
#  ('2023-02', 2000, Decimal('1900.0000')),
#  ('2023-04', 2200, Decimal('2033.3333')),
#  ('2023-05', 2500, Decimal('2233.3333'))]

# %%
# %%sql
# with cte as
# (
# select date_format(created_at, '%Y-%m') as "year_month",
# sum(case when purchase_amt > 0 then purchase_amt else 0 end) as "Total amount"
# from amazon_purchases
# group by date_format(created_at, '%Y-%m')
# )
# , cte2 as
# (
# select *,
# avg(`Total amount`) over(order by `Total amount` asc rows between 2 preceding and current row) as "3-monhs-rolling-average"
# from cte
# )
# select `year_month`, `Total amount`, `3-monhs-rolling-average`
# from cte2
# order by `year_month` asc;
# Out:
#  * mysql+pymysql://root:***@localhost
# 6 rows affected.
# [('2023-01', Decimal('1500'), Decimal('1500.0000')),
#  ('2023-02', Decimal('3200'), Decimal('2166.6667')),
#  ('2023-03', Decimal('1800'), Decimal('1650.0000')),
#  ('2023-04', Decimal('3600'), Decimal('3333.3333')),
#  ('2023-05', Decimal('4200'), Decimal('3666.6667')),
#  ('2023-06', Decimal('3200'), Decimal('2733.3333'))]

# %% [markdown]
# ## ---------------------------------------------------------------------------------------------
