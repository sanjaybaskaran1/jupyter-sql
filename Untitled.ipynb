# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql mysql+pymysql://root:easwari@localhost

# %%
# %%sql
# use `subqueries`;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# show tables;
# Out:
#  * mysql+pymysql://root:***@localhost
# 3 rows affected.
# [('department',), ('employees',), ('salary',)]

# %%
# %%sql
# select * from employees;
# Out:
#  * mysql+pymysql://root:***@localhost
# 15 rows affected.
# [(1, 'Lavanya', 101, datetime.date(2020, 3, 15), 'F', 'Manager'),
#  (2, 'Jaanu', 102, datetime.date(2019, 6, 20), 'F', 'Analyst'),
#  (3, 'Lakshith', 101, datetime.date(2021, 1, 10), 'M', 'Developer'),
#  (4, 'Dakshith', 103, datetime.date(2018, 9, 5), 'M', 'Senior Developer'),
#  (5, 'Janani', 102, datetime.date(2022, 9, 1), 'F', 'Intern'),
#  (6, 'Neha', 103, datetime.date(2017, 11, 11), 'F', 'Senior Developer'),
#  (7, 'Rahul', 101, datetime.date(2019, 1, 25), 'M', 'Developer'),
#  (8, 'Priya', 102, datetime.date(2023, 3, 1), 'F', 'Business Analyst'),
#  (9, 'Karthik', 103, datetime.date(2022, 7, 15), 'M', 'QA Engineer'),
#  (10, 'Aarav', 101, datetime.date(2021, 5, 30), 'M', 'HR Executive'),
#  (11, 'Aanya', 102, datetime.date(2024, 2, 20), 'F', 'Data Scientist'),
#  (12, 'Rohan', 103, datetime.date(2020, 12, 10), 'M', 'Project Manager'),
#  (13, 'Meera', 101, datetime.date(2021, 8, 1), 'F', 'HR Specialist'),
# ...

# %%
# %%sql
# select * from department;
# Out:
#  * mysql+pymysql://root:***@localhost
# 3 rows affected.
# [(101, 'HR', 'New York'),
#  (102, 'IT', 'San Francisco'),
#  (103, 'Engineering', 'Chicago')]

# %%
# %%sql
# select * from salary;
# Out:
#  * mysql+pymysql://root:***@localhost
# 75 rows affected.
# [(1, Decimal('80000.00'), datetime.date(2024, 10, 1)),
#  (1, Decimal('80000.00'), datetime.date(2024, 9, 1)),
#  (1, Decimal('80000.00'), datetime.date(2024, 8, 1)),
#  (1, Decimal('80000.00'), datetime.date(2024, 7, 1)),
#  (1, Decimal('80000.00'), datetime.date(2024, 6, 1)),
#  (2, Decimal('70000.00'), datetime.date(2024, 10, 1)),
#  (2, Decimal('70000.00'), datetime.date(2024, 9, 1)),
#  (2, Decimal('70000.00'), datetime.date(2024, 8, 1)),
#  (2, Decimal('70000.00'), datetime.date(2024, 7, 1)),
#  (2, Decimal('70000.00'), datetime.date(2024, 6, 1)),
#  (3, Decimal('60000.00'), datetime.date(2024, 10, 1)),
#  (3, Decimal('60000.00'), datetime.date(2024, 9, 1)),
#  (3, Decimal('60000.00'), datetime.date(2024, 8, 1)),
#  (3, Decimal('60000.00'), datetime.date(2024, 7, 1)),
#  (3, Decimal('60000.00'), datetime.date(2024, 6, 1)),
#  (4, Decimal('90000.00'), datetime.date(2024, 10, 1)),
# ...
