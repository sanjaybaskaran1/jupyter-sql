# %%
pip install ipython-sql
# Out:
# ...
#
# ...

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:easwari@localhost/subqueries

# %%
# %%sql
# use subqueries;
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 0 rows affected.
# []

# %%
# %%sql
# show tables;
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 3 rows affected.
# [('department',), ('employees',), ('salary',)]

# %%
# %%sql
# select * from employees;
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 15 rows affected.
# [(1, 'Lavanya', 101, datetime.date(2020, 3, 15), 'F', 'Manager'),
#  (2, 'Jaanu', 102, datetime.date(2019, 6, 20), 'F', 'Analyst'),
#  (3, 'Lakshith', 101, datetime.date(2021, 1, 10), 'M', 'Developer'),
#  (4, 'Dakshith', 103, datetime.date(2018, 9, 5), 'M', 'Senior Developer'),
#  (5, 'Janani', 102, datetime.date(2022, 9, 1), 'F', 'Intern'),
#  (6, 'Neha', 103, datetime.date(2017, 11, 11), 'F', 'Senior Developer'),
#  (7, 'Rahul', 101, datetime.date(2019, 1, 25), 'M', 'Developer'),
#  (8, 'Priya', 102, datetime.date(2023, 3, 1), 'F', 'Business Analyst'),
#  (9, 'Karthik', 103, datetime.date(2022, 7, 15), 'M', 'QA Engineer'),
#  (10, 'Aarav', 101, datetime.date(2021, 5, 30), 'M', 'HR Executive'),
#  (11, 'Aanya', 102, datetime.date(2024, 2, 20), 'F', 'Data Scientist'),
#  (12, 'Rohan', 103, datetime.date(2020, 12, 10), 'M', 'Project Manager'),
# ...

# %%
# %%sql
# select * from department;
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 3 rows affected.
# [(101, 'HR', 'New York'),
#  (102, 'IT', 'San Francisco'),
#  (103, 'Engineering', 'Chicago')]

# %%
# %%sql
# select * from salary;
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 75 rows affected.
# [(1, Decimal('80000.00'), datetime.date(2024, 10, 1)),
#  (1, Decimal('80000.00'), datetime.date(2024, 9, 1)),
#  (1, Decimal('80000.00'), datetime.date(2024, 8, 1)),
#  (1, Decimal('80000.00'), datetime.date(2024, 7, 1)),
#  (1, Decimal('80000.00'), datetime.date(2024, 6, 1)),
#  (2, Decimal('70000.00'), datetime.date(2024, 10, 1)),
#  (2, Decimal('70000.00'), datetime.date(2024, 9, 1)),
#  (2, Decimal('70000.00'), datetime.date(2024, 8, 1)),
#  (2, Decimal('70000.00'), datetime.date(2024, 7, 1)),
#  (2, Decimal('70000.00'), datetime.date(2024, 6, 1)),
#  (3, Decimal('60000.00'), datetime.date(2024, 10, 1)),
#  (3, Decimal('60000.00'), datetime.date(2024, 9, 1)),
#  (3, Decimal('60000.00'), datetime.date(2024, 8, 1)),
#  (3, Decimal('60000.00'), datetime.date(2024, 7, 1)),
#  (3, Decimal('60000.00'), datetime.date(2024, 6, 1)),
#  (4, Decimal('90000.00'), datetime.date(2024, 10, 1)),
# ...

# %% [markdown]
# -----------> questions based on single row sub query

# %%
# %%sql
# select dept_id from department where dept_name = 'HR';
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 1 rows affected.
# [(101,)]

# %%
select dept_id,emp_id, name, gender, designation from employees where dept_id = (101);

# %% [markdown]
# ---------> single row subquery use (<,=,>)
# --------->display the employee details of hr department

# %%
# %%sql
# select dept_id,emp_id, name, gender, designation from employees where dept_id =
# (select dept_id from department where dept_name = 'HR');
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 5 rows affected.
# [(101, 1, 'Lavanya', 'F', 'Manager'),
#  (101, 3, 'Lakshith', 'M', 'Developer'),
#  (101, 7, 'Rahul', 'M', 'Developer'),
#  (101, 10, 'Aarav', 'M', 'HR Executive'),
#  (101, 13, 'Meera', 'F', 'HR Specialist')]

# %% [markdown]
# ---------> single row subquery use (<,=,>)
# --------->display the employee details of  department otherthan HR

# %%
# %%sql
# select dept_id,emp_id, name, gender, designation from employees where dept_id >
# (select dept_id from department where dept_name = 'HR');
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 10 rows affected.
# [(102, 2, 'Jaanu', 'F', 'Analyst'),
#  (102, 5, 'Janani', 'F', 'Intern'),
#  (102, 8, 'Priya', 'F', 'Business Analyst'),
#  (102, 11, 'Aanya', 'F', 'Data Scientist'),
#  (102, 14, 'Vikram', 'M', 'Software Engineer'),
#  (103, 4, 'Dakshith', 'M', 'Senior Developer'),
#  (103, 6, 'Neha', 'F', 'Senior Developer'),
#  (103, 9, 'Karthik', 'M', 'QA Engineer'),
#  (103, 12, 'Rohan', 'M', 'Project Manager'),
#  (103, 15, 'Sneha', 'F', 'Product Manager')]

# %% [markdown]
# ---------> single row subquery use (<,=,>)
# --------->display the employee details of  departments HR and Engineering

# %%
# %%sql
# select dept_id,emp_id, name, gender, designation from employees where dept_id <
# (select dept_id from department where dept_name = 'IT');
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 5 rows affected.
# [(101, 1, 'Lavanya', 'F', 'Manager'),
#  (101, 3, 'Lakshith', 'M', 'Developer'),
#  (101, 7, 'Rahul', 'M', 'Developer'),
#  (101, 10, 'Aarav', 'M', 'HR Executive'),
#  (101, 13, 'Meera', 'F', 'HR Specialist')]

# %%
# %%sql
# select join_date from employees where name = 'Lavanya' ;
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 1 rows affected.
# [(datetime.date(2020, 3, 15),)]

# %% [markdown]
# ------> display the employee detals who joined after lavanya

# %%
select emp_id,name,join_date from employees where join_date > ('2020-03-15');

# %%
# %%sql
# select emp_id,name,join_date from employees where join_date >
# (select join_date from employees where name = 'Lavanya');
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 10 rows affected.
# [(3, 'Lakshith', datetime.date(2021, 1, 10)),
#  (5, 'Janani', datetime.date(2022, 9, 1)),
#  (8, 'Priya', datetime.date(2023, 3, 1)),
#  (9, 'Karthik', datetime.date(2022, 7, 15)),
#  (10, 'Aarav', datetime.date(2021, 5, 30)),
#  (11, 'Aanya', datetime.date(2024, 2, 20)),
#  (12, 'Rohan', datetime.date(2020, 12, 10)),
#  (13, 'Meera', datetime.date(2021, 8, 1)),
#  (14, 'Vikram', datetime.date(2024, 3, 5)),
#  (15, 'Sneha', datetime.date(2022, 11, 20))]

# %%
------------> questions based on multiple row sub queries

# %%
# %%sql
# select dept_id,dept_name from department where dept_name in('HR','IT');
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 2 rows affected.
# [(101, 'HR'), (102, 'IT')]

# %% [markdown]
# -------> multiple row sub queries use (in) or (not in)
# ------> display all the employees in hr and it department

# %%
# %%sql
# select * from employees where dept_id in
# (
# select dept_id from department where dept_name in('HR','IT')
# );
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 10 rows affected.
# [(1, 'Lavanya', 101, datetime.date(2020, 3, 15), 'F', 'Manager'),
#  (3, 'Lakshith', 101, datetime.date(2021, 1, 10), 'M', 'Developer'),
#  (7, 'Rahul', 101, datetime.date(2019, 1, 25), 'M', 'Developer'),
#  (10, 'Aarav', 101, datetime.date(2021, 5, 30), 'M', 'HR Executive'),
#  (13, 'Meera', 101, datetime.date(2021, 8, 1), 'F', 'HR Specialist'),
#  (2, 'Jaanu', 102, datetime.date(2019, 6, 20), 'F', 'Analyst'),
#  (5, 'Janani', 102, datetime.date(2022, 9, 1), 'F', 'Intern'),
#  (8, 'Priya', 102, datetime.date(2023, 3, 1), 'F', 'Business Analyst'),
#  (11, 'Aanya', 102, datetime.date(2024, 2, 20), 'F', 'Data Scientist'),
#  (14, 'Vikram', 102, datetime.date(2024, 3, 5), 'M', 'Software Engineer')]

# %% [markdown]
# -------> multiple row sub queries use (in) or (not in)
# ------> display all the employees not in hr and it department
# ------> and filter the result based on designation (Manager and Business Analyst)

# %%
# %%sql
# select * from employees where dept_id in
# (
# select dept_id from department where dept_name  in('HR','IT')
# ) and designation in('Manager','Business Analyst');
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 2 rows affected.
# [(1, 'Lavanya', 101, datetime.date(2020, 3, 15), 'F', 'Manager'),
#  (8, 'Priya', 102, datetime.date(2023, 3, 1), 'F', 'Business Analyst')]

# %% [markdown]
# -------> multiple row sub queries use (in) or (not in)
# ------> display all the employees not in hr and it department

# %%
# %%sql
# select * from employees where dept_id in
# (
# select dept_id from department where dept_name in('HR','IT')
# ) and designation in('Manager', 'Business Analyst');

# %% [markdown]
# -------> multiple row sub queries use (in) or (not in)
# ------> display all the employees not in the hr and it department

# %%
select * from employees where dept_id in
(
select dept_id from department where dept_name not in('HR','IT')
);
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 5 rows affected.
# [(4, 'Dakshith', 103, datetime.date(2018, 9, 5), 'M', 'Senior Developer'),
#  (6, 'Neha', 103, datetime.date(2017, 11, 11), 'F', 'Senior Developer'),
#  (9, 'Karthik', 103, datetime.date(2022, 7, 15), 'M', 'QA Engineer'),
#  (12, 'Rohan', 103, datetime.date(2020, 12, 10), 'M', 'Project Manager'),
#  (15, 'Sneha', 103, datetime.date(2022, 11, 20), 'F', 'Product Manager')]

# %% [markdown]
# ----------> question based on subqueries with joins

# %%
# %%sql
# select avg(salary) as `avg salary` from salary;
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 1 rows affected.
# [(Decimal('72000.000000'),)]

# %%
# %%sql
# select emp_id from salary where salary >
# (select avg(salary) from salary);
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 30 rows affected.
# [(1,),
#  (1,),
#  (1,),
#  (1,),
#  (1,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (6,),
#  (6,),
#  (6,),
#  (6,),
#  (6,),
#  (8,),
#  (8,),
#  (8,),
#  (8,),
#  (8,),
#  (11,),
#  (11,),
#  (11,),
#  (11,),
#  (11,),
#  (12,),
#  (12,),
#  (12,),
#  (12,),
#  (12,)]

# %% [markdown]
# ----> subqueries with joins
# -----> find the employee and salary details of the employees
# ------> whose salary is higher than the average salary

# %%
# %%sql
# select e.name, e.gender,e.designation, s.salary, s.salary_date,
# case when salary > (select avg(salary) from salary) then "salary above avg salary" else "salary below avg salary" end as `salary detail`
# from (employees as e) inner join (salary as s)
# on e.emp_id = s.emp_id
# where e.emp_id in
# (
# select emp_id from salary where salary >
# (select avg(salary) from salary)
# );
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 30 rows affected.
# [('Lavanya', 'F', 'Manager', Decimal('80000.00'), datetime.date(2024, 10, 1), 'salary above avg salary'),
#  ('Lavanya', 'F', 'Manager', Decimal('80000.00'), datetime.date(2024, 9, 1), 'salary above avg salary'),
#  ('Lavanya', 'F', 'Manager', Decimal('80000.00'), datetime.date(2024, 8, 1), 'salary above avg salary'),
#  ('Lavanya', 'F', 'Manager', Decimal('80000.00'), datetime.date(2024, 7, 1), 'salary above avg salary'),
#  ('Lavanya', 'F', 'Manager', Decimal('80000.00'), datetime.date(2024, 6, 1), 'salary above avg salary'),
#  ('Dakshith', 'M', 'Senior Developer', Decimal('90000.00'), datetime.date(2024, 10, 1), 'salary above avg salary'),
#  ('Dakshith', 'M', 'Senior Developer', Decimal('90000.00'), datetime.date(2024, 9, 1), 'salary above avg salary'),
#  ('Dakshith', 'M', 'Senior Developer', Decimal('90000.00'), datetime.date(2024, 8, 1), 'salary above avg salary'),
# ...

# %% [markdown]
# ----> subqueries with joins
# -----> find the employee and salary details of the employees
# ------> whose salary is lesser than the average salary

# %%
# %%sql
# select e.name, e.gender,e.designation, s.salary, s.salary_date,
# case when salary > (select avg(salary) from salary) then "salary above avg salary" else "salary below avg salary" end as `salary detail`
# from (employees as e) inner join (salary as s)
# on e.emp_id = s.emp_id
# where e.emp_id in
# (
# select emp_id from salary where salary <
# (select avg(salary) from salary)
# );
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 35 rows affected.
# [('Jaanu', 'F', 'Analyst', Decimal('70000.00'), datetime.date(2024, 10, 1), 'salary below avg salary'),
#  ('Jaanu', 'F', 'Analyst', Decimal('70000.00'), datetime.date(2024, 9, 1), 'salary below avg salary'),
#  ('Jaanu', 'F', 'Analyst', Decimal('70000.00'), datetime.date(2024, 8, 1), 'salary below avg salary'),
#  ('Jaanu', 'F', 'Analyst', Decimal('70000.00'), datetime.date(2024, 7, 1), 'salary below avg salary'),
#  ('Jaanu', 'F', 'Analyst', Decimal('70000.00'), datetime.date(2024, 6, 1), 'salary below avg salary'),
#  ('Lakshith', 'M', 'Developer', Decimal('60000.00'), datetime.date(2024, 10, 1), 'salary below avg salary'),
#  ('Lakshith', 'M', 'Developer', Decimal('60000.00'), datetime.date(2024, 9, 1), 'salary below avg salary'),
#  ('Lakshith', 'M', 'Developer', Decimal('60000.00'), datetime.date(2024, 8, 1), 'salary below avg salary'),
# ...

# %%
# %%sql
# use joins;
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 0 rows affected.
# []

# %%
# %%sql
# select * from employees;
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 5 rows affected.
# [(1, 'sanjay'), (2, 'lavanya'), (3, 'jaanu'), (4, 'lakshith'), (5, 'Keerthu')]

# %%
# %%sql
# select * from departments;
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 5 rows affected.
# [(1, 'HR'), (2, 'Finance'), (3, 'IT'), (4, 'Marketing'), (5, 'Sales')]

# %%
# %%sql
# select *
# from employees e inner join departments d
# on e.emp_no = d.emp_no;
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 5 rows affected.
# [(1, 'sanjay', 1, 'HR'),
#  (2, 'lavanya', 2, 'Finance'),
#  (3, 'jaanu', 3, 'IT'),
#  (4, 'lakshith', 4, 'Marketing'),
#  (5, 'Keerthu', 5, 'Sales')]

# %%
# %%sql
# select *
# from employees e inner join departments d
# on e.emp_no = d.emp_no
# where d.dept_name = 'HR';
# Out:
#  * mysql+pymysql://root:***@localhost/subqueries
# 1 rows affected.
# [(1, 'sanjay', 1, 'HR')]
